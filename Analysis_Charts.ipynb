# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/Users/akshatpatel/Downloads/Random Data /daily_gym_attendance_workout_data.csv')

# %%
# %pip install nbmerge
# Out:
# Requirement already satisfied: nbmerge in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (0.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !nbmerge Final_analysis.ipynb Analysis_Charts.ipynb > main_analysis.ipynb
